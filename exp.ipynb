# %%
import pandas as pd
from pathlib import Path

# %%
beneficiaries.csv
customers.csv
customer_behavior.csv
customer_beneficiaries.csv
customer_devices.csv
devices.csv
merchants.csv
sanction_list.csv
transactions.csv
transaction_analysis_logs.csv

# %%
# Data folder path
DATA_DIR = Path("Data/CSV_Files")

# Load datasets
beneficiaries = pd.read_csv(DATA_DIR / "beneficiaries.csv")
customers = pd.read_csv(DATA_DIR / "customers.csv")
customer_behavior = pd.read_csv(DATA_DIR / "customer_behavior.csv")
customer_beneficiaries = pd.read_csv(DATA_DIR / "customer_beneficiaries.csv")
customer_devices = pd.read_csv(DATA_DIR / "customer_devices.csv")
devices = pd.read_csv(DATA_DIR / "devices.csv")
merchants = pd.read_csv(DATA_DIR / "merchants.csv")
sanction_list = pd.read_csv(DATA_DIR / "sanction_list.csv")
transactions = pd.read_csv(DATA_DIR / "transactions.csv")
transaction_analysis_logs = pd.read_csv(DATA_DIR / "transaction_analysis_logs.csv")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
audit_logs.head()
# Out:
#       audit_id transaction_id customer_id  fraud_probability  behavior_score  \
# 0  AUD00000000    TXN00000000   CUST11860               22.0            9.05
# 1  AUD00000001    TXN00000001   CUST10233               92.0           88.57
# 2  AUD00000002    TXN00000002   CUST10109               92.0           87.30
# 3  AUD00000003    TXN00000003   CUST10963               83.0           78.18
# 4  AUD00000004    TXN00000004   CUST11020               22.0            5.17
#
#    graph_score  sanction_score  overall_risk_score risk_category  decision  \
# 0         9.42             0.0                22.0           LOW  APPROVED
# 1        87.89             0.0                92.0          HIGH   BLOCKED
# 2        85.17             0.0                92.0          HIGH   BLOCKED
# 3        28.26             0.0                83.0          HIGH   BLOCKED
# 4        18.84             0.0                22.0           LOW  APPROVED
#
# ...

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'customer_id', 'receiver_account', 'merchant_id',
#        'transaction_timestamp', 'transaction_type', 'transaction_amount',
#        'currency', 'payment_method', 'transaction_status', 'device_id',
#        'ip_address', 'origin_country', 'destination_country',
#        'is_international', 'transaction_frequency_24h',
#        'avg_transaction_amount_7d', 'failed_transaction_count_24h',
#        'unusual_amount_flag', 'unusual_location_flag',
#        'multiple_transactions_short_time', 'high_risk_device_flag',
#        'velocity_flag', 'fraud_flag', 'fraud_risk', 'created_at'],
#       dtype='object')

# %%
transactions.head()
# Out:
#   transaction_id customer_id receiver_account merchant_id  \
# 0    TXN00000000   CUST11860    ACC8760139014     MER0053
# 1    TXN00000001   CUST10233    ACC8657075548     MER0059
# 2    TXN00000002   CUST10109    ACC3780475472     MER0097
# 3    TXN00000003   CUST10963    ACC3869961166     MER0045
# 4    TXN00000004   CUST11020    ACC9447304615     MER0034
#
#   transaction_timestamp transaction_type  transaction_amount currency  \
# 0   2026-04-07 13:18:00         TRANSFER             1449.97      INR
# 1   2026-03-11 09:56:00             WIRE             9684.04      INR
# 2   2026-05-14 23:23:00             CARD            18227.65      INR
# 3   2026-04-11 11:09:00         TRANSFER            12060.11      INR
# 4   2026-05-31 11:41:00             WIRE              785.07      INR
#
#   payment_method transaction_status  ... avg_transaction_amount_7d  \
# 0         ONLINE            SUCCESS  ...                   1334.35
# ...

# %%
transactions[:1]["transaction_amount"].values[0]
# Out:
# np.float64(1449.97)

# %%
audit_logs[:1]["behavior_agent_output"].values[0]
# Out:
# 'Behavioral Agent: Input dynamics show transaction speed variance. Interaction cadence signature matches automated bot behaviors: False.'

# %%
list(transactions.columns)
# Out:
# ['transaction_id',
#  'customer_id',
#  'receiver_account',
#  'merchant_id',
#  'transaction_timestamp',
#  'transaction_type',
#  'transaction_amount',
#  'currency',
#  'payment_method',
#  'transaction_status',
#  'device_id',
#  'ip_address',
#  'origin_country',
#  'destination_country',
#  'is_international',
#  'transaction_frequency_24h',
#  'avg_transaction_amount_7d',
#  'failed_transaction_count_24h',
#  'unusual_amount_flag',
#  'unusual_location_flag',
#  'multiple_transactions_short_time',
#  'high_risk_device_flag',
#  'velocity_flag',
#  'fraud_flag',
#  'fraud_risk',
#  'created_at']

# %%
from IPython.display import IFrame

IFrame("https://www.google.com", width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://www.google.com"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
